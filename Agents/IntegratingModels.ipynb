# %%
import os
from dotenv import load_dotenv
load_dotenv(dotenv_path="../.env")
from IPython.display import display, Markdown

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["OPENROUTER_API_KEY"] = os.getenv("OPENROUTER_API_KEY")
os.environ["XAI_API_KEY"] = os.getenv("XAI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="google_genai:gemini-3.1-flash-lite")
resposne = model.invoke("What SaaS business model can i start with genAI as a fresher in software developer")
ai_text = resposne.content[0]["text"]
display(Markdown(ai_text))
# Out:
# As a fresher in software development, the best way to approach a GenAI SaaS is to **solve a "boring" problem for a specific niche** rather than trying to build a general-purpose AI tool (which requires massive compute and data).
#
# Here are four SaaS business models tailored for a developer starting out, ranked by technical complexity and market viability:
#
# ---
#
# ### 1. The "Niche Content Repurposer"
# Instead of building a generic AI writer, build a tool that converts **one specific format into another for a specific industry.**
#
# *   **The Idea:** A tool that takes long-form YouTube videos from **Real Estate Agents** and automatically turns them into 5 LinkedIn posts, a newsletter summary, and a blog post, all formatted for their specific brand voice.
# *   **Why it works:** Real estate agents are busy and have money. They need social presence but hate writing.
# ...

# %% [markdown]
# Dont have credits for grok(Elon's AI Model)

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="grok-4.20-reasoning")
resposne = model.invoke("What SaaS business model can i start with genAI as a fresher in software developer")
display(Markdown(resposne))

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
model = init_chat_model(model="openrouter:deepseek/deepseek-chat")
messages = [
    HumanMessage(content="What is the distance between the Earth and the Moon?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# The average distance between the Earth and the Moon is approximately **384,400 kilometers (238,855 miles)**. This distance can vary slightly because the Moon orbits the Earth in an elliptical path, so its distance ranges from about **363,300 kilometers (225,623 miles)** at its closest (perigee) to **405,500 kilometers (251,966 miles)** at its farthest (apogee).

# %%
import importlib.metadata

version = importlib.metadata.version("langchain-openrouter")
print(f"langchain-openrouter version: {version}")
# Out:
# langchain-openrouter version: 0.2.3
